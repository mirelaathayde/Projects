# %%
import pandas as pd

# %%
file = pd.read_excel('MonitoramentoHIVAids-Brasil.xlsx')

# %%
file.head(10)
# Out:
#   Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 0                                                NaN
# 1                                      Casos de AIDS
# 2                                              Total
# 3                                             Homens
# 4                                           Mulheres
# 5                                  Menores de 5 anos
# 6                                 Entre 15 e 24 anos
# 7                                                NaN
# 8  FONTE: MS/SVS/Departamento de Doenças de Condi...
# 9                                                NaN
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1      Total  1980-2007       2008      2009.0      2010.0      2011.0
# 2    1011617     511487      41225     41192.0     40775.0     42772.0
# ...

# %%
df1 = file.loc[2:6]

# %%
df1.columns = ['CasosAids', 'Total','1980_2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']

# %%
df1.head(10)
# Out:
#             CasosAids    Total 1980_2007   2008     2009     2010     2011  \
# 2               Total  1011617    511487  41225  41192.0  40775.0  42772.0
# 3              Homens   664721    337260  24705  24982.0  25302.0  26845.0
# 4            Mulheres   346791    174193  16509  16205.0  15470.0  15924.0
# 5   Menores de 5 anos    17773     12694    578    560.0    548.0    469.0
# 6  Entre 15 e 24 anos   113055     56422   3669   3859.0   3914.0   4374.0
#
#       2012     2013   2014     2015   2016     2017     2018     2019   2020
# 2  42480.0  43368.0  42135  40995.0  39425  38535.0  38040.0  37308.0  11880
# 3  26965.0  28106.0  27806  27768.0  26979  26809.0  26619.0  26141.0   8434
# 4  15513.0  15256.0  14325  13219.0  12438  11717.0  11419.0  11161.0   3442
# 5    491.0    442.0    395    348.0    339    295.0    269.0    270.0     75
# 6   4776.0   4992.0   5039   5138.0   4919   4990.0   4764.0   4667.0   1532

# %%
df1.to_excel(r'Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL SICLOM por ano de diagnóstico.xlsx', index = False)

# %%
df2 = file.loc[14:18]

# %%
df2 = df2.drop(columns=['Unnamed: 13','Unnamed: 14','Unnamed: 15'])

# %%
df2.columns = ['Taxa de detecção','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

# %%
df2.head(10)
# Out:
#       Taxa de detecção  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 14               Geral  21.7  21.5  21.4  22.2  21.9  21.6  20.8  20.1  19.1
# 15              Homens  26.4  26.4  26.5  27.9  27.8  28.7  28.2  27.9  26.9
# 16            Mulheres    17  16.5  15.6  15.9  15.3  14.9  13.9  12.7  11.9
# 17   Menores de 5 anos   3.8   3.6     4   3.4   3.5   2.9   2.6   2.4   2.3
# 18  Entre 15 e 24 anos  10.5  11.1  11.3  12.6  13.8  14.4  14.6  14.9  14.4
#
#     2017  2018  2019
# 14  18.6  18.2  17.8
# 15  26.5  26.1  25.4
# 16  11.1  10.7  10.4
# 17   2.1   1.9   1.9
# 18  14.7  14.1  14.0

# %%
df2.to_excel(r'Taxa de detecção (por 100.000 hab.) de casos de aids notificados no Sinan, declarados no SIM e registrados no SISCEL SICLOM, por ano de diagnóstico.xlsx', index = False)

# %%
df3 = file.loc[26:27]

# %%
df3.head(10)
# Out:
#    Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 26                                     Razão de Sexos
# 27                                                NaN
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 26        1.5        1.5        1.6         1.7         1.7         1.8
# 27        NaN        NaN        NaN         NaN         NaN         NaN
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 26         1.9         2.1        2.2          2.3         2.3          2.3
# 27         NaN         NaN        NaN          NaN         NaN          NaN
#
#     Unnamed: 13  Unnamed: 14 Unnamed: 15
# 26          NaN          NaN         NaN
# 27          NaN          NaN         NaN

# %%
df3 = df3.drop(27)

# %%
df3.head()
# Out:
#    Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 26                                     Razão de Sexos
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 26        1.5        1.5        1.6         1.7         1.7         1.8
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 26         1.9         2.1        2.2          2.3         2.3          2.3
#
#     Unnamed: 13  Unnamed: 14 Unnamed: 15
# 26          NaN          NaN         NaN

# %%
df3 = df3.drop(columns=['Unnamed: 13','Unnamed: 14','Unnamed: 15'])

# %%
df3.columns = ['-','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

# %%
df3.head()
# Out:
#                  - 2008 2009 2010  2011  2012  2013  2014  2015 2016  2017  \
# 26  Razão de Sexos  1.5  1.5  1.6   1.7   1.7   1.8   1.9   2.1  2.2   2.3
#
#    2018  2019
# 26  2.3   2.3

# %%
df3.to_excel(r'Razão de Sexos de casos de aids notificados no Sinan, declarados no SIM e registrados no Siscel Siclom por ano de diagnóstico.xlsx', index = False)

# %%
df4 = file.loc[34:35]

# %%
df4.head(10)
# Out:
#    Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 34                                   HIV em gestantes
# 35                      Taxa de detecção em gestantes
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 34     134328      41329       6376      6505.0      6569.0      6671.0
# 35          -          -        2.2         2.3         2.3         2.3
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 34      7127.0      7179.0       7727       7958.0        7929       7909.0
# 35         2.5         2.5        2.6          2.6         2.8          2.7
#
#     Unnamed: 13  Unnamed: 14 Unnamed: 15
# 34       8589.0       8312.0        4148
# 35          2.9          2.8           -

# %%
df4.columns = ['-','Total','1980 - 2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']

# %%
df4.head()
# Out:
#                                 -   Total 1980 - 2007  2008    2009    2010  \
# 34               HIV em gestantes  134328       41329  6376  6505.0  6569.0
# 35  Taxa de detecção em gestantes       -           -   2.2     2.3     2.3
#
#       2011    2012    2013  2014    2015  2016    2017    2018    2019  2020
# 34  6671.0  7127.0  7179.0  7727  7958.0  7929  7909.0  8589.0  8312.0  4148
# 35     2.3     2.5     2.5   2.6     2.6   2.8     2.7     2.9     2.8     -

# %%
df4.to_excel(r'Gestantes infectadas pelo HIV (casos e taxa de detecção por 1.000 nascidos vivos) por ano do parto.xlsx', index = False)

# %%
df5 = file.loc[43:44]

# %%
df5.head()
# Out:
#    Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 43                                    Óbitos por AIDS
# 44                          Taxa bruta de mortalidade
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 43     281156     136940      11839     12134.0     12151.0     12151.0
# 44          -          -        6.2         6.3         6.4         6.3
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 43     12073.0     12564.0      12575      12667.0       12540      11735.0
# 44         6.2         6.2        6.2          6.2         6.1          5.7
#
#     Unnamed: 13  Unnamed: 14 Unnamed: 15
# 43      11222.0      10565.0         NaN
# 44          5.4          5.0         NaN

# %%
df5 = df5.drop(columns=['Unnamed: 15'])

# %%
df5.head()
# Out:
#    Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 43                                    Óbitos por AIDS
# 44                          Taxa bruta de mortalidade
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 43     281156     136940      11839     12134.0     12151.0     12151.0
# 44          -          -        6.2         6.3         6.4         6.3
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 43     12073.0     12564.0      12575      12667.0       12540      11735.0
# 44         6.2         6.2        6.2          6.2         6.1          5.7
#
#     Unnamed: 13  Unnamed: 14
# 43      11222.0      10565.0
# 44          5.4          5.0

# %%
df5.columns = ['-','Total','1980-2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

# %%
df5.head()
# Out:
#                             -   Total 1980-2007   2008     2009     2010  \
# 43            Óbitos por AIDS  281156    136940  11839  12134.0  12151.0
# 44  Taxa bruta de mortalidade       -         -    6.2      6.3      6.4
#
#        2011     2012     2013   2014     2015   2016     2017     2018  \
# 43  12151.0  12073.0  12564.0  12575  12667.0  12540  11735.0  11222.0
# 44      6.3      6.2      6.2    6.2      6.2    6.1      5.7      5.4
#
#        2019
# 43  10565.0
# 44      5.0

# %%
df5.to_excel(r'Óbitos por causa básica aids e Coeficiente de mortalidade bruto por aids (por 100.000 hab.), por ano do óbito.xlsx', index = False)

# %%
df6 = file.loc[52:57]

# %%
df6.columns = ['Cor ou Raça','Total','1980-2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']

# %%
df6.head(10)
# Out:
#    Cor ou Raça   Total 1980-2007   2008     2009     2010     2011     2012  \
# 52      Branca  242424    102818  13591  13456.0  13703.0  14163.0  13792.0
# 53       Preta   54810     21140   3028   3011.0   3027.0   3104.0   3115.0
# 54     Amarela    2696      1158    128    136.0    141.0    151.0    150.0
# 55       Parda  187799     55613   9524  10230.0  10848.0  11495.0  12272.0
# 56    Indígena    1445       437     68     82.0    105.0     93.0    105.0
# 57    Ignorada  271099    250542   2339   2362.0   2127.0   2104.0   1849.0
#
#        2013   2014     2015   2016     2017    2018    2019  2020
# 52  13164.0  11950  10833.0   9562   9010.0  7865.0  6581.0  1936
# 53   3103.0   2869   2676.0   2639   2461.0  2181.0  1915.0   541
# 54    130.0    118    113.0    106    104.0   111.0   116.0    34
# 55  13052.0  12491  11270.0  10332  10231.0  9539.0  8428.0  2474
# 56     87.0     74     79.0     83     75.0    73.0    60.0    24
# ...

# %%
df6.to_excel(r'Casos de aids notificados no Sinan, segundo raça e cor por ano de diagnóstico.xlsx', index = False)

# %%
df7 = file.loc[78:88]

# %%
df7.head(10)
# Out:
#    Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 78                                         Analfabeto
# 79                           1ª a 4ª série incompleta
# 80                                  4ª série completa
# 81                           5ª a 8ª série incompleta
# 82                               Fundamental completo
# 83                                   Médio incompleto
# 84                                     Médio completo
# 85                                Superior incompleto
# 86                                  Superior completo
# 87                                           Ignorado
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 78      20824      13867        595       629.0       680.0       718.0
# 79     104581      80861       2575      2406.0      2331.0      2405.0
# 80      22827       5197       2099      1990.0      1787.0      1850.0
# ...

# %%
df7.columns = ['Escolaridade','Total','1980-2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']

# %%
df7.head()
# Out:
#                 Escolaridade   Total 1980-2007  2008    2009    2010    2011  \
# 78                Analfabeto   20824     13867   595   629.0   680.0   718.0
# 79  1ª a 4ª série incompleta  104581     80861  2575  2406.0  2331.0  2405.0
# 80         4ª série completa   22827      5197  2099  1990.0  1787.0  1850.0
# 81  5ª a 8ª série incompleta  160829    107837  5279  5301.0  5263.0  5277.0
# 82      Fundamental completo   38386      7723  3093  3026.0  3047.0  2972.0
#
#       2012    2013  2014    2015  2016    2017    2018    2019 2020
# 78   674.0   685.0   596   518.0   488   471.0   420.0   398.0   85
# 79  2384.0  2251.0  2060  1863.0  1548  1342.0  1240.0  1032.0  283
# 80  1777.0  1566.0  1496  1318.0  1086   943.0   842.0   685.0  191
# 81  5250.0  5285.0  4649  3953.0  3570  3275.0  2836.0  2409.0  645
# 82  2935.0  3018.0  2625  2280.0  2102  1948.0  1731.0  1462.0  424

# %%
df7.to_excel(r'Casos de aids notificados no Sinan, segundo escolaridade por ano de diagnóstico.xlsx', index = False)

# %%
df8 = file.loc[140:148]

# %%
df8.head()
# Out:
#     Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 140                                        Homossexual
# 141                                          Bissexual
# 142                                      Heterossexual
# 143                                                UDI
# 144                                         Hemofílico
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 140     122538      58919       3869      4272.0      4758.0      5312.0
# 141      50625      33188       1456      1471.0      1543.0      1665.0
# 142     385936     204567      16847     16965.0     17388.0     17887.0
# 143      73220      63062       1336      1295.0      1162.0      1143.0
# 144       1305       1229         13         6.0         8.0         6.0
#
#      Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# ...

# %%
df8.columns = ['Categoria de Exposição','Total','1980-2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']

# %%
df8.head(10)
# Out:
#     Categoria de Exposição   Total 1980-2007   2008     2009     2010  \
# 140            Homossexual  122538     58919   3869   4272.0   4758.0
# 141              Bissexual   50625     33188   1456   1471.0   1543.0
# 142          Heterossexual  385936    204567  16847  16965.0  17388.0
# 143                    UDI   73220     63062   1336   1295.0   1162.0
# 144             Hemofílico    1305      1229     13      6.0      8.0
# 145             Transfusão    2374      2301      9     11.0      8.0
# 146    Acid. Mt. Biológico      23         6      -      2.0      1.0
# 147   Transmissão Vertical   17976     12154    651    588.0    595.0
# 148               Ignorado  357620    136061  17044  16582.0  15312.0
#
#         2011     2012     2013   2014     2015   2016     2017     2018  \
# 140   5312.0   5846.0   6149.0   5971   5786.0   5482   5534.0   5093.0
# 141   1665.0   1608.0   1666.0   1516   1384.0   1270   1335.0   1178.0
# ...

# %%
df8.to_excel(r'Casos de aids notificados no Sinan em indivíduos do sexo masculino com 13 anos de idade ou mais, segundo categoria de exposição hierarquizada, por ano de diagnóstico.xlsx', index = False)

# %%
df9 = file.loc[200:201]

# %%
df9.head()
# Out:
#     Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 200                Total de casos notificados no SINAN
# 201      Total de casos notificados em outros sistemas
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 200          -          -      29514     26598.0     24188.0     23117.0
# 201          -          -      12621     14397.0     15237.0     15418.0
#
#      Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 200         NaN         NaN        NaN          NaN         NaN          NaN
# 201         NaN         NaN        NaN          NaN         NaN          NaN
#
#      Unnamed: 13  Unnamed: 14 Unnamed: 15
# 200          NaN          NaN         NaN
# 201          NaN          NaN         NaN

# %%
df9 = df9.drop(columns=['Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15'])

# %%
df9.head()
# Out:
#     Tabela 1 - Casos de AIDS notificados no Sinan, declarados no SIM e registrados no SISCEL/SICLOM por ano de diagnóstico.  \
# 200                Total de casos notificados no SINAN
# 201      Total de casos notificados em outros sistemas
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 200          -          -      29514     26598.0     24188.0     23117.0
# 201          -          -      12621     14397.0     15237.0     15418.0

# %%
df9.columns = ['-','2014','2015','2016','2017','2018','2019']

# %%
df9.head()
# Out:
#                                                  - 2014 2015   2016     2017  \
# 200            Total de casos notificados no SINAN    -    -  29514  26598.0
# 201  Total de casos notificados em outros sistemas    -    -  12621  14397.0
#
#         2018     2019
# 200  24188.0  23117.0
# 201  15237.0  15418.0

# %%
df8.to_excel(r'Casos de aids notificados no Sinan, declarados no SIM e registrados no Siscel Siclom, segundo origem dos dados, por ano de diagnóstico.xlsx', index = False)
